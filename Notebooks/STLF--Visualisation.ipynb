# %% [markdown]
# # Year -  Month - MW

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/2-day-load-data.xlsx')
df
# Out:
#            date           MW
# 0    2017-01-01  3536.238770
# 1    2017-01-02  3639.738770
# 2    2017-01-03  3673.321289
# 3    2017-01-04  3898.860840
# 4    2017-01-05  3547.965820
# ...         ...          ...
# 1090 2019-12-27  4976.180664
# 1091 2019-12-28  4708.879395
# 1092 2019-12-29  4831.750488
# 1093 2019-12-30  5298.331055
# 1094 2019-12-31  5244.527832
#
# [1095 rows x 2 columns]

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import DatetimeTickFormatter

# %%
x = df['date']
y = df['MW']

p = figure(title="Date vs MW", 
           sizing_mode="stretch_width",
           x_axis_type='datetime',
           x_axis_label='Date',
           y_axis_label='MW')

p.line(x, y, legend_label="Visualisation", line_width=2)
p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")

# %%
output_notebook()
show(p)
# Out:
#   <div class="bk-root" id="e8392be2-ce03-4ae3-8fbd-69d2cca3a399" data-root-id="5259"></div>

# %% [markdown]
# ## Convering data to for month-wise analysis with average MW for that month

# %%
df.groupby(pd.PeriodIndex(df['date'], freq="M"))['MW'].mean().reset_index()
# Out:
#        date           MW
# 0   2017-01  3802.992810
# 1   2017-02  3570.103734
# 2   2017-03  3448.389916
# 3   2017-04  4497.599666
# 4   2017-05  5463.267358
# 5   2017-06  5539.018392
# 6   2017-07  5485.938981
# 7   2017-08  5434.594207
# 8   2017-09  5025.448560
# 9   2017-10  4094.285046
# 10  2017-11  3444.246208
# 11  2017-12  3715.665748
# 12  2018-01  4071.515987
# 13  2018-02  3704.221767
# 14  2018-03  3453.504946
# 15  2018-04  4270.359538
# 16  2018-05  5467.236092
# 17  2018-06  6297.223079
# 18  2018-07  5907.381253
# 19  2018-08  5582.889318
# 20  2018-09  4692.657292
# 21  2018-10  4015.904817
# 22  2018-11  3349.223389
# 23  2018-12  3816.618936
# 24  2019-01  4201.174104
# 25  2019-02  4010.336312
# 26  2019-03  3558.088907
# 27  2019-04  4416.927970
# 28  2019-05  5436.591072
# 29  2019-06  6372.714355
# 30  2019-07  6020.531187
# 31  2019-08  5677.350885
# 32  2019-09  5638.912321
# 33  2019-10  3922.480996
# 34  2019-11  3429.986263
# 35  2019-12  4155.903596

# %%
x = df['date']
y = df['MW']

p1 = figure(title="Date vs MW", 
           sizing_mode="stretch_width",
           max_width=900,
           x_axis_type='datetime',
           x_axis_label='Date',
           y_axis_label='MW')

p1.line(x, y, legend_label="Visualisation", line_width=2)
p1.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")

# %%
show(p1)
# Out:
#   <div class="bk-root" id="b332f393-bcce-4b6e-b68a-8991aef63dc4" data-root-id="7499"></div>

# %%
x = df['date']
y = df['MW']

p = figure(title="Date vs MW", 
           sizing_mode="stretch_width",
           max_width=900,
           x_axis_type='datetime',
           x_axis_label='Date',
           y_axis_label='MW')

p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")
p.vbar(x=x,
       top=y,
       legend_label="MW",
       width=0.1,
       bottom=0,
       fill_alpha=0.5,
       color="red",
       alpha=0.5)
# Out:
# GlyphRenderer(id='7367', ...)

# %%
show(p1)
# Out:
#   <div class="bk-root" id="29be2d91-812f-42d9-b833-cdf04fd63de6" data-root-id="6612"></div>

# %% [markdown]
# # Holiday, Weekday and Weekend Trends
#
#
#
# Convention to be followed:
#
# * 0 - Weekdays (M-F)
# * 1 - Weekends (S, S)
# * 2 - Public Holidays

# %%
import pandas as pd 
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import DatetimeTickFormatter

# %%
df = pd.read_excel('/content/6-day-load-holiday-data.xlsx')
df
# Out:
#            date  day           MW
# 0    2017-01-01    2  3536.238770
# 1    2017-01-02    0  3639.738770
# 2    2017-01-03    0  3673.321289
# 3    2017-01-04    0  3898.860840
# 4    2017-01-05    2  3547.965820
# ...         ...  ...          ...
# 1090 2019-12-27    0  4976.180664
# 1091 2019-12-28    1  4708.879395
# 1092 2019-12-29    1  4831.750488
# 1093 2019-12-30    0  5298.331055
# 1094 2019-12-31    0  5244.527832
#
# [1095 rows x 3 columns]

# %% [markdown]
# ### Creating dataset based on type of day

# %%
weekday_df = df.loc[df['day'] == 0]
weekend_df = df.loc[df['day'] == 1]
holiday_df = df.loc[df['day'] == 2]

# %% [markdown]
# ## Weekday

# %%
x = weekday_df['date']
y = weekday_df['MW']

p = figure(title="Date vs MW", 
           sizing_mode="stretch_width",
           max_width=900,
           x_axis_type='datetime',
           x_axis_label='Date',
           y_axis_label='MW')

p.line(x, y, legend_label="Visualisation", line_width=2)
p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")
show(p)
# Out:
#   <div class="bk-root" id="9f56ff54-ecb5-4c19-9130-5b86d0ac2912" data-root-id="8588"></div>

# %%
x = weekday_df['date']
y = weekday_df['MW']

p = figure(title="Date vs MW", 
           sizing_mode="stretch_width",
           max_width=900,
           x_axis_type='datetime',
           x_axis_label='Date',
           y_axis_label='MW')

p.circle(x, y, size=15, line_color="navy", fill_color="orange", fill_alpha=0.5)
p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")
show(p)
# Out:
#   <div class="bk-root" id="9c7681eb-7fd7-4263-a862-f3d3f74e5df5" data-root-id="10866"></div>

# %% [markdown]
# ## Weekend

# %%
x = weekend_df['date']
y = weekend_df['MW']

p = figure(title="Date vs MW", 
           sizing_mode="stretch_width",
           max_width=900,
           x_axis_type='datetime',
           x_axis_label='Date',
           y_axis_label='MW')

p.line(x, y, legend_label="Visualisation", line_width=2)
p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")
show(p)
# Out:
#   <div class="bk-root" id="c285d0a5-af58-4684-9ca2-f2fd20a047e8" data-root-id="9132"></div>

# %% [markdown]
# ## Public Holiday

# %%
x = holiday_df['date']
y = holiday_df['MW']

p = figure(title="Date vs MW", 
           sizing_mode="stretch_width",
           max_width=900,
           x_axis_type='datetime',
           x_axis_label='Date',
           y_axis_label='MW')

p.line(x, y, legend_label="Visualisation", line_width=2)
p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")
show(p)
# Out:
#   <div class="bk-root" id="2110457d-dc43-4167-816f-e94b6d9b2dad" data-root-id="9697"></div>
